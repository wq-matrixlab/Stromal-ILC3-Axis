# %%
import numpy as np   
import pandas as pd
import scanpy as sc
import seaborn as sb
import matplotlib.pyplot as plt       
sc.settings.verbosity = 3           
sc.settings.set_figure_params(dpi=80, dpi_save=300, fontsize=8, figsize=(4,4), facecolor='white', transparent=True)

# %%
adata = sc.read_h5ad('Fibroblast_annotation.h5ad')

# %%
sc.tl.paga(adata, groups='cell type')
sc.pl.paga(adata, color=['cell type'], threshold=0.09, 
           save="page.pdf"
           )
# Out:
# running PAGA
#     finished: added
#     'paga/connectivities', connectivities adjacency (adata.uns)
#     'paga/connectivities_tree', connectivities subtree (adata.uns) (0:00:01)
# --> added 'pos', the PAGA positions (adata.uns['paga'])
# WARNING: saving figure to file figures\pagapage.pdf
